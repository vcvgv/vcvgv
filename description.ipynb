# %%
#单变量描述统计

##无序类别变量描述统计

import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_spss(R'data\identity.sav')

# %%
df['民族'].value_counts(normalize=True)
# Out:
# 民族
# 汉族      0.424277
# 回族      0.152601
# 藏族      0.057803
# 蒙古族     0.057803
# 壮族      0.054335
# 土家族     0.053179
# 维吾尔族    0.053179
# 苗族      0.039306
# 彝族      0.017341
# 白族      0.017341
# 满族      0.012717
# 哈萨克族    0.011561
# 瑶族      0.009249
# 布依族     0.008092
# 侗族      0.005780
# 东乡族     0.004624
# 黎族      0.003468
# 哈尼族     0.003468
# 水族      0.002312
# 仫佬族     0.002312
# 羌族      0.002312
# 畲族      0.001156
# 土族      0.001156
# 其他      0.001156
# 保安族     0.001156
# 裕固族     0.001156
# 毛难族     0.001156
# Name: proportion, dtype: float64

# %%
x=df['民族'].value_counts().index
y=df['民族'].value_counts(normalize=True).values*100
fig,ax2=plt.subplots()
labels=df['民族'].value_counts().index
ax2.pie(y,autopct='%1.1f%%',labels=labels,textprops=dict(color="w"))
plt.show()
# Out:
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 27721 (\N{CJK UNIFIED IDEOGRAPH-6C49}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26063 (\N{CJK UNIFIED IDEOGRAPH-65CF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 34255 (\N{CJK UNIFIED IDEOGRAPH-85CF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 33945 (\N{CJK UNIFIED IDEOGRAPH-8499}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21476 (\N{CJK UNIFIED IDEOGRAPH-53E4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22766 (\N{CJK UNIFIED IDEOGRAPH-58EE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22303 (\N{CJK UNIFIED IDEOGRAPH-571F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 23478 (\N{CJK UNIFIED IDEOGRAPH-5BB6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32500 (\N{CJK UNIFIED IDEOGRAPH-7EF4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21566 (\N{CJK UNIFIED IDEOGRAPH-543E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 23572 (\N{CJK UNIFIED IDEOGRAPH-5C14}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 33495 (\N{CJK UNIFIED IDEOGRAPH-82D7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 24413 (\N{CJK UNIFIED IDEOGRAPH-5F5D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 30333 (\N{CJK UNIFIED IDEOGRAPH-767D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 28385 (\N{CJK UNIFIED IDEOGRAPH-6EE1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21704 (\N{CJK UNIFIED IDEOGRAPH-54C8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 33832 (\N{CJK UNIFIED IDEOGRAPH-8428}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20811 (\N{CJK UNIFIED IDEOGRAPH-514B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 29814 (\N{CJK UNIFIED IDEOGRAPH-7476}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20381 (\N{CJK UNIFIED IDEOGRAPH-4F9D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20375 (\N{CJK UNIFIED IDEOGRAPH-4F97}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 19996 (\N{CJK UNIFIED IDEOGRAPH-4E1C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20065 (\N{CJK UNIFIED IDEOGRAPH-4E61}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 40654 (\N{CJK UNIFIED IDEOGRAPH-9ECE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 23612 (\N{CJK UNIFIED IDEOGRAPH-5C3C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 27700 (\N{CJK UNIFIED IDEOGRAPH-6C34}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20203 (\N{CJK UNIFIED IDEOGRAPH-4EEB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20332 (\N{CJK UNIFIED IDEOGRAPH-4F6C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32652 (\N{CJK UNIFIED IDEOGRAPH-7F8C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 30066 (\N{CJK UNIFIED IDEOGRAPH-7572}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20854 (\N{CJK UNIFIED IDEOGRAPH-5176}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20182 (\N{CJK UNIFIED IDEOGRAPH-4ED6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20445 (\N{CJK UNIFIED IDEOGRAPH-4FDD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 23433 (\N{CJK UNIFIED IDEOGRAPH-5B89}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 35029 (\N{CJK UNIFIED IDEOGRAPH-88D5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22266 (\N{CJK UNIFIED IDEOGRAPH-56FA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 27611 (\N{CJK UNIFIED IDEOGRAPH-6BDB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 38590 (\N{CJK UNIFIED IDEOGRAPH-96BE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
x=df['民族'].value_counts().index
y=df['民族'].value_counts(normalize=True).values*100
fig,ax2=plt.subplots()
labels=df['民族'].value_counts().index
ax2.pie(y,autopct='%1.1f%%',labels=labels,textprops=dict(color="w"))
plt.show()
# Out:
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 27721 (\N{CJK UNIFIED IDEOGRAPH-6C49}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26063 (\N{CJK UNIFIED IDEOGRAPH-65CF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 34255 (\N{CJK UNIFIED IDEOGRAPH-85CF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 33945 (\N{CJK UNIFIED IDEOGRAPH-8499}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21476 (\N{CJK UNIFIED IDEOGRAPH-53E4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22766 (\N{CJK UNIFIED IDEOGRAPH-58EE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22303 (\N{CJK UNIFIED IDEOGRAPH-571F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 23478 (\N{CJK UNIFIED IDEOGRAPH-5BB6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32500 (\N{CJK UNIFIED IDEOGRAPH-7EF4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21566 (\N{CJK UNIFIED IDEOGRAPH-543E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 23572 (\N{CJK UNIFIED IDEOGRAPH-5C14}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 33495 (\N{CJK UNIFIED IDEOGRAPH-82D7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 24413 (\N{CJK UNIFIED IDEOGRAPH-5F5D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 30333 (\N{CJK UNIFIED IDEOGRAPH-767D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 28385 (\N{CJK UNIFIED IDEOGRAPH-6EE1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21704 (\N{CJK UNIFIED IDEOGRAPH-54C8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 33832 (\N{CJK UNIFIED IDEOGRAPH-8428}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20811 (\N{CJK UNIFIED IDEOGRAPH-514B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 29814 (\N{CJK UNIFIED IDEOGRAPH-7476}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20381 (\N{CJK UNIFIED IDEOGRAPH-4F9D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20375 (\N{CJK UNIFIED IDEOGRAPH-4F97}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 19996 (\N{CJK UNIFIED IDEOGRAPH-4E1C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20065 (\N{CJK UNIFIED IDEOGRAPH-4E61}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 40654 (\N{CJK UNIFIED IDEOGRAPH-9ECE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 23612 (\N{CJK UNIFIED IDEOGRAPH-5C3C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 27700 (\N{CJK UNIFIED IDEOGRAPH-6C34}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20203 (\N{CJK UNIFIED IDEOGRAPH-4EEB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20332 (\N{CJK UNIFIED IDEOGRAPH-4F6C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32652 (\N{CJK UNIFIED IDEOGRAPH-7F8C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 30066 (\N{CJK UNIFIED IDEOGRAPH-7572}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20854 (\N{CJK UNIFIED IDEOGRAPH-5176}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20182 (\N{CJK UNIFIED IDEOGRAPH-4ED6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20445 (\N{CJK UNIFIED IDEOGRAPH-4FDD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 23433 (\N{CJK UNIFIED IDEOGRAPH-5B89}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 35029 (\N{CJK UNIFIED IDEOGRAPH-88D5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22266 (\N{CJK UNIFIED IDEOGRAPH-56FA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 27611 (\N{CJK UNIFIED IDEOGRAPH-6BDB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 38590 (\N{CJK UNIFIED IDEOGRAPH-96BE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#有序定类变量描述统计，可增加次数和累计比例的统计。可采用饼图或柱状
df['年级'].value_counts()
# Out:
# 年级
# 大一    307
# 大二    278
# 大三    172
# 大四     94
# 预科     14
# Name: count, dtype: int64

# %%
from pyreadstat import pyreadstat
国家认同调查数据表, metadata = pyreadstat.read_sav(R'C:\Users\陈好\Desktop\vcvgv\data\identity.sav',apply_value_formats=True,formats_as_ordered_category=True)
result = 国家认同调查数据表['会打多少分'].value_counts(sort=False)

# %%
国家认同调查数据表['年级'].value_counts(sort=False)
# Out:
# 年级
# 预科     14
# 大一    307
# 大二    278
# 大三    172
# 大四     94
# Name: count, dtype: int64

# %%
df_result=pd.DataFrame(国家认同调查数据表['年级'].value_counts(sort=False))
df_result['累计求和'] = df_result['count'].cumsum()
# df_result['新变量1']=1
# df_result['新变量2']=df_result.新变量1+1
df_result['比例']=国家认同调查数据表['年级'].value_counts(normalize=True)
df_result['累计比例']=df_result['比例'].cumsum

# %%
df_result
# Out:
#     count  累计求和        比例                                               累计比例
# 年级
# 预科     14    14  0.016185  <bound method NDFrame._add_numeric_operations....
# 大一    307   321  0.354913  <bound method NDFrame._add_numeric_operations....
# 大二    278   599  0.321387  <bound method NDFrame._add_numeric_operations....
# 大三    172   771  0.198844  <bound method NDFrame._add_numeric_operations....
# 大四     94   865  0.108671  <bound method NDFrame._add_numeric_operations....

# %%
x=df_result.index

# %%
x=df_result.index
y=df_result['count'].values
fig,ax2=plt.subplots()
ax2.bar(x,y)
plt.show()
# Out:
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 31185 (\N{CJK UNIFIED IDEOGRAPH-79D1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20108 (\N{CJK UNIFIED IDEOGRAPH-4E8C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 19977 (\N{CJK UNIFIED IDEOGRAPH-4E09}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\陈好\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22235 (\N{CJK UNIFIED IDEOGRAPH-56DB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
